# %%
import ultralytics
import torch
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=/yolo_training_dataset/datasest.yaml epochs=100 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.35 🚀 Python-3.8.10 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24109MiB)
# ...
